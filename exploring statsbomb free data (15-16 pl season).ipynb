# %%
import pandas as pd
from statsbombpy import sb
from mplsoccer import Pitch

# %%
import datetime

# %%
sb.competitions()
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 65              55         43         Europe           UEFA Euro
# 66              35         75         Europe  UEFA Europa League
# 67              53        106         Europe   UEFA Women's Euro
# 68              72        107  International   Women's World Cup
# 69              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
df = sb.matches (competition_id = 2, season_id = 27)
df
# Out:
#      match_id  match_date      kick_off               competition     season  \
# 0     3754058  2016-01-02  16:00:00.000  England - Premier League  2015/2016
# 1     3754245  2015-10-17  16:00:00.000  England - Premier League  2015/2016
# 2     3754136  2015-12-19  18:30:00.000  England - Premier League  2015/2016
# 3     3754037  2016-04-30  16:00:00.000  England - Premier League  2015/2016
# 4     3754039  2016-02-13  16:00:00.000  England - Premier League  2015/2016
# ..        ...         ...           ...                       ...        ...
# 375   3754020  2015-08-17  21:00:00.000  England - Premier League  2015/2016
# 376   3754267  2015-08-15  16:00:00.000  England - Premier League  2015/2016
# 377   3754141  2015-08-09  14:30:00.000  England - Premier League  2015/2016
# 378   3754128  2015-08-08  16:00:00.000  England - Premier League  2015/2016
# 379   3754078  2015-08-08  18:30:00.000  England - Premier League  2015/2016
#
# ...

# %%
liverpool_matches = df[(df['away_team'] == 'Liverpool') | (df['home_team'] == 'Liverpool')]

# %%
liverpool_matches_sorted = liverpool_matches.sort_values(by='match_date')
liverpool_matches_sorted
# Out:
#      match_id  match_date      kick_off               competition     season  \
# 182   3753985  2015-08-09  17:00:00.000  England - Premier League  2015/2016
# 375   3754020  2015-08-17  21:00:00.000  England - Premier League  2015/2016
# 185   3754129  2015-08-24  21:00:00.000  England - Premier League  2015/2016
# 42    3753984  2015-08-29  16:00:00.000  England - Premier League  2015/2016
# 172   3754003  2015-09-12  18:30:00.000  England - Premier League  2015/2016
# 50    3754040  2015-09-20  17:00:00.000  England - Premier League  2015/2016
# 112   3754212  2015-09-26  16:00:00.000  England - Premier League  2015/2016
# 58    3754060  2015-10-04  14:30:00.000  England - Premier League  2015/2016
# 108   3754198  2015-10-17  13:45:00.000  England - Premier League  2015/2016
# 120   3754230  2015-10-25  17:15:00.000  England - Premier League  2015/2016
# 69    3754098  2015-10-31  13:45:00.000  England - Premier League  2015/2016
# ...

# %%
sb.lineups(match_id=3754208)['Liverpool']
# Out:
#     player_id                          player_name    player_nickname  \
# 0        3380              Christian Benteke Liolo  Christian Benteke
# 1        3471                         Dejan Lovren               None
# 2        3473                  James Philip Milner       James Milner
# 3        3493                             Emre Can               None
# 4        3501            Philippe Coutinho Correia  Philippe Coutinho
# 5        3515                 Alberto Moreno Pérez     Alberto Moreno
# 6        3529               Daniel Andre Sturridge   Daniel Sturridge
# 7        3535  Roberto Firmino Barbosa de Oliveira    Roberto Firmino
# 8        3539                       Simon Mignolet               None
# 9        3635                           Jordon Ibe               None
# 10       4090                   Adam David Lallana       Adam Lallana
# 11       4590                Nathaniel Edwin Clyne    Nathaniel Clyne
# ...

# %%
events = sb.events(match_id=3754208)

# %%
events.head(20)
# Out:
#    50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0    NaN                NaN                  NaN                     NaN
# 1    NaN                NaN                  NaN                     NaN
# 2    NaN                NaN                  NaN                     NaN
# 3    NaN                NaN                  NaN                     NaN
# 4    NaN                NaN                  NaN                     NaN
# 5    NaN                NaN                  NaN                     NaN
# 6    NaN                NaN                  NaN                     NaN
# 7    NaN                NaN                  NaN                     NaN
# 8    NaN                NaN                  NaN                     NaN
# 9    NaN                NaN                  NaN                     NaN
# 10   NaN                NaN                  NaN                     NaN
# 11   NaN                NaN                  NaN                     NaN
# ...

# %%
sb.events(match_id=3754208, split=True, flatten_attrs=False)["passes"]
# Out:
#                                         id  index  period     timestamp  \
# 0     83e271d7-76b0-4379-ba48-019201c1bc19      5       1  00:00:00.752
# 1     2bda330b-3033-46c7-a727-be760006a1e2      8       1  00:00:02.944
# 2     8f3c4f3f-756d-4e2e-84ea-b1e00857ba6b     11       1  00:00:05.059
# 3     9812bcbe-5219-4ead-b96c-17c875234f57     13       1  00:00:06.135
# 4     9f5644c9-29ea-49c8-9353-a42cc2bdd798     16       1  00:00:07.282
# ...                                    ...    ...     ...           ...
# 1022  cf9f0b13-ead2-43aa-871a-c0130adc3c96   3694       2  00:48:25.229
# 1023  12c1b3e5-7b42-4423-a306-e2535ce82b27   3699       2  00:48:32.493
# 1024  f8dcd7b8-e007-4c00-8cae-2f8204c2167d   3702       2  00:48:35.422
# 1025  5b17fcb8-23db-469a-91c5-e45f68a76674   3705       2  00:48:38.573
# 1026  bfa4825e-80c6-4498-a9ab-3f986bde2f19   3713       2  00:48:51.374
#
#       minute  second  type  possession possession_team   play_pattern  ...  \
# ...
